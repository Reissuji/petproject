# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn import datasets
from sklearn.decomposition import PCA
import seaborn as sns
# %matplotlib inline
#from pandas_profiling import ProfileReport

# %%
df = pd.read_csv('Dataset_Completo.csv')
df
# Out:
#                     Raza  Altura (cm)  Peso (kg)  Inteligencia (%)  \
# 0              Chihuahua         13.0        2.5              16.0
# 1              Chihuahua         13.5        2.2              16.0
# 2              Chihuahua         13.2        2.1              16.0
# 3              Chihuahua         13.3        2.3              16.0
# 4              Chihuahua         12.8        2.4              16.0
# ..                   ...          ...        ...               ...
# 205  Schnauzer Miniatura         33.6        7.8              87.0
# 206  Schnauzer Miniatura         33.3        7.4              87.0
# 207  Schnauzer Miniatura         32.8        7.9              87.0
# 208  Schnauzer Miniatura         33.9        6.5              87.0
# 209  Schnauzer Miniatura         33.7        7.6              87.0
#
#      Coste total (€)  Vida promedio (años)  Nº Enfermedades graves  \
# 0              19722                 16.20                       2
# 1              19630                 16.80                       1
# 2              19650                 16.40                       2
# 3              19700                 16.70                       1
# 4              19730                 16.10                       2
# ..               ...                   ...                     ...
# 205            14505                 11.79                       3
# 206            14482                 11.81                       2
# 207            14457                 11.85                       3
# 208            14512                 11.78                       2
# 209            14497                 11.80                       3
#
#      Coste anual promedio (€)                Hogar Trucos  \
# 0                        1198  Apartamento pequeño     No
# 1                        1192        Jardín Amplio     No
# 2                        1195  Apartamento pequeño     No
# 3                        1190  Apartamento mediano     No
# 4                        1199        Jardín Amplio     Sí
# ..                        ...                  ...    ...
# 205                      1221        Jardín Amplio     No
# 206                      1226                Finca     Sí
# 207                      1230  Apartamento pequeño     No
# 208                      1220        Jardín Amplio     Sí
# 209                      1223  Apartamento mediano     No
#
#     Actividad física del dueño             Distrito
# 0                    Frecuente          Carabanchel
# 1                         Nada            Salamanca
# 2               Poco frecuente            Salamanca
# 3                Muy frecuente            Chamartín
# 4                    Frecuente   Puente de Vallecas
# ..                         ...                  ...
# 205                       Nada               Centro
# 206              Muy frecuente            Hortaleza
# 207                  Frecuente        Ciudad Lineal
# 208             Poco frecuente  Fuencarral-El Pardo
# 209                       Nada                Usera
#
# [210 rows x 12 columns]

# %%
df[df['Raza']=='Caniche']
# Out:
#        Raza  Altura (cm)  Peso (kg)  Inteligencia (%)  Coste total (€)  \
# 20  Caniche         41.0       25.0              99.0            15898
# 21  Caniche         40.5       25.5              99.0            15910
# 22  Caniche         41.2       24.8              99.0            15890
# 23  Caniche         41.4       25.2              99.0            15905
# 24  Caniche         41.1       24.7              99.0            15885
# 25  Caniche         41.6       25.8              99.0            15920
# 26  Caniche         41.3       25.4              99.0            15902
# 27  Caniche         40.8       25.9              99.0            15878
# 28  Caniche         41.9       24.5              99.0            15930
# 29  Caniche         41.7       25.6              99.0            15915
#
#     Vida promedio (años)  Nº Enfermedades graves  Coste anual promedio (€)  \
# 20                 11.95                       2                      1330
# 21                 11.94                       1                      1328
# 22                 11.97                       2                      1331
# 23                 11.96                       1                      1329
# 24                 11.98                       2                      1332
# 25                 11.93                       1                      1327
# 26                 11.95                       2                      1333
# 27                 11.99                       1                      1334
# 28                 11.92                       2                      1326
# 29                 11.94                       1                      1335
#
#                   Hogar Trucos Actividad física del dueño             Distrito
# 20        Jardín Amplio     Sí                       Nada    Villa de Vallecas
# 21  Apartamento mediano     No                  Frecuente               Latina
# 22        Jardín Amplio     Sí             Poco frecuente            Hortaleza
# 23  Apartamento pequeño     No              Muy frecuente  Fuencarral-El Pardo
# 24        Jardín Amplio     Sí                  Frecuente                Usera
# 25  Apartamento mediano     Sí             Poco frecuente    Villa de Vallecas
# 26                Finca     No                       Nada               Centro
# 27        Jardín Amplio     No                       Nada   Puente de Vallecas
# 28  Apartamento pequeño     Sí              Muy frecuente          Carabanchel
# 29        Jardín Amplio     No                  Frecuente               Latina

# %%
df.dtypes
# Out:
# Raza                           object
# Altura (cm)                   float64
# Peso (kg)                     float64
# Inteligencia (%)              float64
# Coste total (€)                 int64
# Vida promedio (años)          float64
# Nº Enfermedades graves          int64
# Coste anual promedio (€)        int64
# Hogar                          object
# Trucos                         object
# Actividad física del dueño     object
# Distrito                       object
# dtype: object

# %%
df['Raza'].unique()
# Out:
# array(['Chihuahua', 'Springer Spaniel Inglés', 'Caniche',
#        'Braco Alemán de pelo corto', 'Labrador Retriever',
#        'Bichón Maltés', 'Pomerania', 'Golden Retriever', 'Beagle',
#        'Setter Inglés', 'Doberman Pinscher',
#        'Cavalier King Charles Spaniel', 'Rottweiler', 'Pastor Alemán',
#        'Bulldog Francés', 'Gran Danés', 'Bulldog', 'Border Collie',
#        'Husky Siberiano', 'Dachshund', 'Schnauzer Miniatura'],
#       dtype=object)

# %%
df2 = pd.read_csv('info_distritos_madrid.csv',sep=',')
df2
df2 = df2[['Distrito', 'Renta media/pers (€)','Áreas caninas (m²)']]
df2
# Out:
#                Distrito  Renta media/pers (€)  Áreas caninas (m²)
# 0   Fuencarral-El Pardo                 20671                1852
# 1       Moncloa-Aravaca                 24659                2606
# 2                Latina                 13719                1802
# 3           Carabanchel                 12275                2794
# 4                 Usera                 10797                2971
# 5            Villaverde                 11059                 844
# 6    Puente de Vallecas                 10941                3843
# 7     Villa de Vallecas                 13605                1140
# 8             Moratalaz                 15667                2838
# 9             Vicálvaro                 13849                4410
# 10        Ciudad Lineal                 16890                 614
# 11  San Blas-Canillejas                 15115                 609
# 12            Hortaleza                 20500                3852
# 13              Barajas                 19482                5810
# 14               Tetuán                 17026                1246
# 15            Chamartín                 28233                 165
# 16             Chamberí                 25275                 826
# 17               Centro                 19199                 326
# 18               Retiro                 23925                6736
# 19           Arganzuela                 20103                1764
# 20            Salamanca                 25956                 623

# %%
df_merge = pd.merge(df, df2, how='left', on='Distrito')
df_merge.sort_index()
# Out:
#                     Raza  Altura (cm)  Peso (kg)  Inteligencia (%)  \
# 0              Chihuahua         13.0        2.5              16.0
# 1              Chihuahua         13.5        2.2              16.0
# 2              Chihuahua         13.2        2.1              16.0
# 3              Chihuahua         13.3        2.3              16.0
# 4              Chihuahua         12.8        2.4              16.0
# ..                   ...          ...        ...               ...
# 205  Schnauzer Miniatura         33.6        7.8              87.0
# 206  Schnauzer Miniatura         33.3        7.4              87.0
# 207  Schnauzer Miniatura         32.8        7.9              87.0
# 208  Schnauzer Miniatura         33.9        6.5              87.0
# 209  Schnauzer Miniatura         33.7        7.6              87.0
#
#      Coste total (€)  Vida promedio (años)  Nº Enfermedades graves  \
# 0              19722                 16.20                       2
# 1              19630                 16.80                       1
# 2              19650                 16.40                       2
# 3              19700                 16.70                       1
# 4              19730                 16.10                       2
# ..               ...                   ...                     ...
# 205            14505                 11.79                       3
# 206            14482                 11.81                       2
# 207            14457                 11.85                       3
# 208            14512                 11.78                       2
# 209            14497                 11.80                       3
#
#      Coste anual promedio (€)                Hogar Trucos  \
# 0                        1198  Apartamento pequeño     No
# 1                        1192        Jardín Amplio     No
# 2                        1195  Apartamento pequeño     No
# 3                        1190  Apartamento mediano     No
# 4                        1199        Jardín Amplio     Sí
# ..                        ...                  ...    ...
# 205                      1221        Jardín Amplio     No
# 206                      1226                Finca     Sí
# 207                      1230  Apartamento pequeño     No
# 208                      1220        Jardín Amplio     Sí
# 209                      1223  Apartamento mediano     No
#
#     Actividad física del dueño             Distrito  Renta media/pers (€)  \
# 0                    Frecuente          Carabanchel                 12275
# 1                         Nada            Salamanca                 25956
# 2               Poco frecuente            Salamanca                 25956
# 3                Muy frecuente            Chamartín                 28233
# 4                    Frecuente   Puente de Vallecas                 10941
# ..                         ...                  ...                   ...
# 205                       Nada               Centro                 19199
# 206              Muy frecuente            Hortaleza                 20500
# 207                  Frecuente        Ciudad Lineal                 16890
# 208             Poco frecuente  Fuencarral-El Pardo                 20671
# 209                       Nada                Usera                 10797
#
#      Áreas caninas (m²)
# 0                  2794
# 1                   623
# 2                   623
# 3                   165
# 4                  3843
# ..                  ...
# 205                 326
# 206                3852
# 207                 614
# 208                1852
# 209                2971
#
# [210 rows x 14 columns]

# %%
df_merge = df_merge.drop(columns=['Coste total (€)'])
df_merge.to_csv('perretes.csv', sep=',', index=False)

# %%
df_merge['Distrito'].value_counts()
# Out:
# Distrito
# Puente de Vallecas     18
# Carabanchel            15
# Fuencarral-El Pardo    15
# Latina                 14
# Ciudad Lineal          13
# Hortaleza              12
# Centro                 12
# San Blas-Canillejas    11
# Chamberí               10
# Moncloa-Aravaca        10
# Salamanca              10
# Chamartín               9
# Villaverde              9
# Usera                   9
# Tetuán                  9
# Arganzuela              8
# Villa de Vallecas       7
# Retiro                  6
# Moratalaz               5
# Vicálvaro               4
# Barajas                 4
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import OneHotEncoder
# One hot encoding
# Trans
enc = OneHotEncoder(handle_unknown='ignore' ,sparse=False)
enc.fit_transform(df_merge[['Trucos']])

df_merge.loc[:,'Trucos'] = enc.fit_transform(df_merge[['Trucos']])[:,0]
# Out:
# c:\Users\anape\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# c:\Users\anape\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
from sklearn.preprocessing import OrdinalEncoder

# Inicializar el OrdinalEncoder
categories_hogar = ['Apartamento pequeño', 'Apartamento mediano', 'Jardín Amplio', 'Finca']
categories_act = ['Nada', 'Poco frecuente', 'Frecuente', 'Muy frecuente']

encoder = OrdinalEncoder(categories=[categories_hogar, categories_act])
data_encoded= encoder.fit_transform(df_merge[['Hogar', 'Actividad física del dueño']])

df_merge[['Hogar_enc', 'Act.f_enc']] = data_encoded

# Muestra el DataFrame con la codificación ordinal
df_merge

# Ajustar y transformar los datos en la columna categórica
# df_merge['Raza'] = ordinal_encoder.fit_transform(df_merge[['Raza']])
# df_merge['Hogar'] = ordinal_encoder.fit_transform(df_merge[['Hogar']])
# df_merge['Actividad física del dueño'] = ordinal_encoder.fit_transform(df_merge[['Actividad física del dueño']])
# Out:
#                     Raza  Altura (cm)  Peso (kg)  Inteligencia (%)  \
# 0              Chihuahua         13.0        2.5              16.0
# 1              Chihuahua         13.5        2.2              16.0
# 2              Chihuahua         13.2        2.1              16.0
# 3              Chihuahua         13.3        2.3              16.0
# 4              Chihuahua         12.8        2.4              16.0
# ..                   ...          ...        ...               ...
# 205  Schnauzer Miniatura         33.6        7.8              87.0
# 206  Schnauzer Miniatura         33.3        7.4              87.0
# 207  Schnauzer Miniatura         32.8        7.9              87.0
# 208  Schnauzer Miniatura         33.9        6.5              87.0
# 209  Schnauzer Miniatura         33.7        7.6              87.0
#
#      Vida promedio (años)  Nº Enfermedades graves  Coste anual promedio (€)  \
# 0                   16.20                       2                      1198
# 1                   16.80                       1                      1192
# 2                   16.40                       2                      1195
# 3                   16.70                       1                      1190
# 4                   16.10                       2                      1199
# ..                    ...                     ...                       ...
# 205                 11.79                       3                      1221
# 206                 11.81                       2                      1226
# 207                 11.85                       3                      1230
# 208                 11.78                       2                      1220
# 209                 11.80                       3                      1223
#
#                    Hogar Trucos Actividad física del dueño  \
# 0    Apartamento pequeño    1.0                  Frecuente
# 1          Jardín Amplio    1.0                       Nada
# 2    Apartamento pequeño    1.0             Poco frecuente
# 3    Apartamento mediano    1.0              Muy frecuente
# 4          Jardín Amplio    0.0                  Frecuente
# ..                   ...    ...                        ...
# 205        Jardín Amplio    1.0                       Nada
# 206                Finca    0.0              Muy frecuente
# 207  Apartamento pequeño    1.0                  Frecuente
# 208        Jardín Amplio    0.0             Poco frecuente
# 209  Apartamento mediano    1.0                       Nada
#
#                 Distrito  Renta media/pers (€)  Áreas caninas (m²)  Hogar_enc  \
# 0            Carabanchel                 12275                2794        0.0
# 1              Salamanca                 25956                 623        2.0
# 2              Salamanca                 25956                 623        0.0
# 3              Chamartín                 28233                 165        1.0
# 4     Puente de Vallecas                 10941                3843        2.0
# ..                   ...                   ...                 ...        ...
# 205               Centro                 19199                 326        2.0
# 206            Hortaleza                 20500                3852        3.0
# 207        Ciudad Lineal                 16890                 614        0.0
# 208  Fuencarral-El Pardo                 20671                1852        2.0
# 209                Usera                 10797                2971        1.0
#
#      Act.f_enc
# 0          2.0
# 1          0.0
# 2          1.0
# 3          3.0
# 4          2.0
# ..         ...
# 205        0.0
# 206        3.0
# 207        2.0
# 208        1.0
# 209        0.0
#
# [210 rows x 15 columns]

# %%
X = df_merge.drop(columns=['Raza','Distrito','Altura (cm)', 'Vida promedio (años)','Coste total (€)', 'Nº Enfermedades graves', 'Hogar', 'Actividad física del dueño'])
y = df_merge['Raza']
y
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[134], line 1
# ----> 1 X = df_merge.drop(columns=['Raza','Distrito','Altura (cm)', 'Vida promedio (años)','Coste total (€)', 'Nº Enfermedades graves', 'Hogar', 'Actividad física del dueño'])
#       2 y = df_merge['Raza']
#       3 y
#
# File c:\Users\anape\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
#    5351         errors=errors,
#    5352     )
#
# File c:\Users\anape\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:4711, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709 for axis, labels in axes.items():
#    4710     if labels is not None:
# -> 4711         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4713 if inplace:
#    4714     self._update_inplace(obj)
#
# File c:\Users\anape\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:4753, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4751         new_axis = axis.drop(labels, level=level, errors=errors)
#    4752     else:
# -> 4753         new_axis = axis.drop(labels, errors=errors)
#    4754     indexer = axis.get_indexer(new_axis)
#    4756 # Case for non-unique axis
#    4757 else:
#
# File c:\Users\anape\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:6992, in Index.drop(self, labels, errors)
#    6990 if mask.any():
#    6991     if errors != "ignore":
# -> 6992         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    6993     indexer = indexer[~mask]
#    6994 return self.delete(indexer)
#
# KeyError: "['Coste total (€)'] not found in axis"

# %%
X.columns
# Out:
# Index(['Peso (kg)', 'Inteligencia (%)', 'Coste anual promedio (€)', 'Trucos',
#        'Renta media/pers (€)', 'Áreas caninas (m²)', 'Hogar_enc', 'Act.f_enc'],
#       dtype='object')

# %%
y
# Out:
# 0                Chihuahua
# 1                Chihuahua
# 2                Chihuahua
# 3                Chihuahua
# 4                Chihuahua
#               ...
# 205    Schnauzer Miniatura
# 206    Schnauzer Miniatura
# 207    Schnauzer Miniatura
# 208    Schnauzer Miniatura
# 209    Schnauzer Miniatura
# Name: Raza, Length: 210, dtype: object

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.33, random_state=42, stratify=y)

# %%
y_train.value_counts()
# Out:
# Raza
# Golden Retriever                 7
# Husky Siberiano                  7
# Bulldog Francés                  7
# Border Collie                    7
# Beagle                           7
# Chihuahua                        7
# Pastor Alemán                    7
# Braco Alemán de pelo corto       7
# Rottweiler                       7
# Springer Spaniel Inglés          7
# Pomerania                        7
# Bichón Maltés                    7
# Dachshund                        7
# Schnauzer Miniatura              7
# Gran Danés                       6
# Setter Inglés                    6
# Caniche                          6
# Labrador Retriever               6
# Cavalier King Charles Spaniel    6
# Bulldog                          6
# Doberman Pinscher                6
# Name: count, dtype: int64

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler,MinMaxScaler

grid_params = {
    'tree__max_depth' : range (1,100,5),
    #'tree__min_samples_split': np.linspace(0.05, 0.5, 5)
    }

pipe = Pipeline([('scaler', MinMaxScaler()), ('tree', DecisionTreeClassifier())]) #para algunos modelos es necesarios escalar
#y para otros modelos no. Pero, como minmaxscaler no modifica distribución, no pasa nada porque se haga siempre (si no sabemos qué modelo vamos a entrenar)

#gs = GridSearchCV(KNeighborsClassifier(), grid_params, cv = 5, verbose=1, scoring= 'precision',return_train_score=False)
gs = GridSearchCV(pipe, grid_params, cv = 3, verbose=1, scoring= 'precision_weighted',return_train_score=True)

# %%
gs.fit(X,y)
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# c:\Users\anape\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\anape\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\anape\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\anape\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\anape\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\anape\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\anape\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\anape\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\anape\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\anape\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\anape\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\anape\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\anape\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\anape\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\anape\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\anape\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\anape\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\anape\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('scaler', MinMaxScaler()),
#                                        ('tree', DecisionTreeClassifier())]),
#              param_grid={'tree__max_depth': range(1, 100, 5)},
#              return_train_score=True, scoring='precision_weighted', verbose=1)

# %%
gs.best_params_ 
# gs.best_estimator_
# Out:
# {'tree__max_depth': 16}

# %%
pd.DataFrame.from_dict(gs.cv_results_['params'])
# Out:
#     tree__max_depth
# 0                 1
# 1                 6
# 2                11
# 3                16
# 4                21
# 5                26
# 6                31
# 7                36
# 8                41
# 9                46
# 10               51
# 11               56
# 12               61
# 13               66
# 14               71
# 15               76
# 16               81
# 17               86
# 18               91
# 19               96

# %%
results = pd.merge(pd.DataFrame(gs.cv_results_), pd.DataFrame.from_dict(gs.cv_results_['params']), left_index=True, right_index=True)
results.head(2)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.014268      0.010353         0.014984        0.005294
# 1       0.020826      0.002952         0.019718        0.015082
#
#   param_tree__max_depth                  params  split0_test_score  \
# 0                     1  {'tree__max_depth': 1}           0.044776
# 1                     6  {'tree__max_depth': 6}           0.285593
#
#    split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0           0.044776           0.044776         0.044776    6.938894e-18
# 1           0.281366           0.259615         0.275525    1.138123e-02
#
#    rank_test_score  split0_train_score  split1_train_score  \
# 0               20            0.052632            0.052632
# 1               19            0.353846            0.329167
#
#    split2_train_score  mean_train_score  std_train_score  tree__max_depth
# 0            0.052632          0.052632         0.000000                1
# 1            0.303571          0.328861         0.020526                6

# %%
X.columns
# Out:
# Index(['Peso (kg)', 'Inteligencia (%)', 'Coste anual promedio (€)', 'Trucos',
#        'Renta media/pers (€)', 'Áreas caninas (m²)', 'Hogar_enc', 'Act.f_enc'],
#       dtype='object')

# %%
gs.best_estimator_
# Out:
# Pipeline(steps=[('scaler', MinMaxScaler()),
#                 ('tree', DecisionTreeClassifier(max_depth=16))])

# %%
gs.best_estimator_.feature_importance
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[120], line 1
# ----> 1 gs.best_estimator_.feature_importance
#
# AttributeError: 'Pipeline' object has no attribute 'feature_importance'

# %%
col = 'tree__max_depth'
fig, ax= plt.subplots(figsize=(12,6))
results.plot.scatter(col,'mean_train_score', ax=ax, label='train', color='b')
results.plot.scatter(col,'mean_test_score', ax=ax, label='test', color='r')
plt.legend()

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler,MinMaxScaler

grid_params = {
    'tree__max_depth' : range (15,24),
    #'tree__min_samples_split': np.linspace(0.05, 0.5, 5)
    }

pipe = Pipeline([('scaler', MinMaxScaler()), ('tree', DecisionTreeClassifier())]) #para algunos modelos es necesarios escalar
#y para otros modelos no. Pero, como minmaxscaler no modifica distribución, no pasa nada porque se haga siempre (si no sabemos qué modelo vamos a entrenar)

#gs = GridSearchCV(KNeighborsClassifier(), grid_params, cv = 5, verbose=1, scoring= 'precision',return_train_score=False)
gs = GridSearchCV(pipe, grid_params, cv = 3, verbose=1, scoring= 'precision_weighted',return_train_score=True)

# %%
gs.fit(X,y)
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('scaler', MinMaxScaler()),
#                                        ('tree', DecisionTreeClassifier())]),
#              param_grid={'tree__max_depth': range(15, 24)},
#              return_train_score=True, scoring='precision_weighted', verbose=1)

# %%
gs.best_params_
# Out:
# {'tree__max_depth': 18}

# %%
pd.DataFrame.from_dict(gs.cv_results_['params'])
# Out:
#    tree__max_depth
# 0               18
# 1               19
# 2               20
# 3               21

# %%
results = pd.merge(pd.DataFrame(gs.cv_results_), pd.DataFrame.from_dict(gs.cv_results_['params']), left_index=True, right_index=True)
results.head(2)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.034500      0.009503         0.022456        0.002447
# 1       0.020769      0.005264         0.012043        0.005167
#
#   param_tree__max_depth                   params  split0_test_score  \
# 0                    15  {'tree__max_depth': 15}           0.982857
# 1                    16  {'tree__max_depth': 16}           0.982857
#
#    split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0                1.0           0.971429         0.984762        0.011742
# 1                1.0           0.971429         0.984762        0.011742
#
#    rank_test_score  split0_train_score  split1_train_score  \
# 0                4                 1.0                 1.0
# 1                4                 1.0                 1.0
#
#    split2_train_score  mean_train_score  std_train_score  tree__max_depth
# 0                 1.0               1.0              0.0               15
# 1                 1.0               1.0              0.0               16

# %%
col = 'tree__max_depth'
fig, ax= plt.subplots(figsize=(12,6))
results.plot.scatter(col,'mean_train_score', ax=ax, label='train', color='b')
results.plot.scatter(col,'mean_test_score', ax=ax, label='test', color='r')
plt.legend()

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler,MinMaxScaler

grid_params = {
    'tree__max_depth' : range (15,24),
    'tree__min_samples_split': np.linspace(0.05, 0.5, 5)
    }

pipe = Pipeline([('scaler', MinMaxScaler()), ('tree', DecisionTreeClassifier())]) #para algunos modelos es necesarios escalar
#y para otros modelos no. Pero, como minmaxscaler no modifica distribución, no pasa nada porque se haga siempre (si no sabemos qué modelo vamos a entrenar)

#gs = GridSearchCV(KNeighborsClassifier(), grid_params, cv = 5, verbose=1, scoring= 'precision',return_train_score=False)
gs = GridSearchCV(pipe, grid_params, cv = 3, verbose=1, scoring= 'recall_weighted',return_train_score=True)

# %%
gs.fit(X,y)
# Out:
# Fitting 3 folds for each of 45 candidates, totalling 135 fits
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('scaler', MinMaxScaler()),
#                                        ('tree', DecisionTreeClassifier())]),
#              param_grid={'tree__max_depth': range(15, 24),
#                          'tree__min_samples_split': array([0.05  , 0.1625, 0.275 , 0.3875, 0.5   ])},
#              return_train_score=True, scoring='recall_weighted', verbose=1)

# %%
pd.DataFrame.from_dict(gs.cv_results_['params'])
# Out:
#     tree__max_depth  tree__min_samples_split
# 0                15                   0.0500
# 1                15                   0.1625
# 2                15                   0.2750
# 3                15                   0.3875
# 4                15                   0.5000
# 5                16                   0.0500
# 6                16                   0.1625
# 7                16                   0.2750
# 8                16                   0.3875
# 9                16                   0.5000
# 10               17                   0.0500
# 11               17                   0.1625
# 12               17                   0.2750
# 13               17                   0.3875
# 14               17                   0.5000
# 15               18                   0.0500
# 16               18                   0.1625
# 17               18                   0.2750
# 18               18                   0.3875
# 19               18                   0.5000
# 20               19                   0.0500
# 21               19                   0.1625
# 22               19                   0.2750
# 23               19                   0.3875
# 24               19                   0.5000
# 25               20                   0.0500
# 26               20                   0.1625
# 27               20                   0.2750
# 28               20                   0.3875
# 29               20                   0.5000
# 30               21                   0.0500
# 31               21                   0.1625
# 32               21                   0.2750
# 33               21                   0.3875
# 34               21                   0.5000
# 35               22                   0.0500
# 36               22                   0.1625
# 37               22                   0.2750
# 38               22                   0.3875
# 39               22                   0.5000
# 40               23                   0.0500
# 41               23                   0.1625
# 42               23                   0.2750
# 43               23                   0.3875
# 44               23                   0.5000

# %%
col1 = 'tree__max_depth'
col2 = 'tree__min_samples_split'
fig, ax= plt.subplots(figsize=(12,6), nrows=1, ncols=2)
results.plot.scatter(col1,'mean_train_score', ax=ax[0], label='train', color='b')
results.plot.scatter(col1,'mean_test_score', ax=ax[0], label='test', color='r')
results.plot.scatter(col2,'mean_train_score', ax=ax[1], label='train', color='b')
results.plot.scatter(col2,'mean_test_score', ax=ax[1], label='test', color='r')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\anape\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'tree__min_samples_split'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[102], line 6
#       4 results.plot.scatter(col1,'mean_train_score', ax=ax[0], label='train', color='b')
#       5 results.plot.scatter(col1,'mean_test_score', ax=ax[0], label='test', color='r')
# ----> 6 results.plot.scatter(col2,'mean_train_score', ax=ax[1], label='train', color='b')
#       7 results.plot.scatter(col2,'mean_test_score', ax=ax[1], label='test', color='r')
#       8 plt.legend()
#
# File c:\Users\anape\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_core.py:1751, in PlotAccessor.scatter(self, x, y, s, c, **kwargs)
#    1663 def scatter(
#    1664     self,
#    1665     x: Hashable,
#    (...)
#    1669     **kwargs,
#    1670 ) -> PlotAccessor:
#    1671     """
#    1672     Create a scatter plot with varying marker point size and color.
#    1673
#    (...)
#    1749         ...                       colormap='viridis')
#    1750     """
# -> 1751     return self(kind="scatter", x=x, y=y, s=s, c=c, **kwargs)
#
# File c:\Users\anape\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_core.py:976, in PlotAccessor.__call__(self, *args, **kwargs)
#     974 if kind in self._dataframe_kinds:
#     975     if isinstance(data, ABCDataFrame):
# --> 976         return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     977     else:
#     978         raise ValueError(f"plot kind {kind} can only be used for data frames")
#
# File c:\Users\anape\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File c:\Users\anape\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_matplotlib\core.py:453, in MPLPlot.generate(self)
#     451 self._compute_plot_data()
#     452 self._setup_subplots()
# --> 453 self._make_plot()
#     454 self._add_table()
#     455 self._make_legend()
#
# File c:\Users\anape\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_matplotlib\core.py:1267, in ScatterPlot._make_plot(self)
#    1264 else:
#    1265     label = None
#    1266 scatter = ax.scatter(
# -> 1267     data[x].values,
#    1268     data[y].values,
#    1269     c=c_values,
#    1270     label=label,
#    1271     cmap=cmap,
#    1272     norm=norm,
#    1273     **self.kwds,
#    1274 )
#    1275 if cb:
#    1276     cbar_label = c if c_is_column else ""
#
# File c:\Users\anape\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File c:\Users\anape\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'tree__min_samples_split'
