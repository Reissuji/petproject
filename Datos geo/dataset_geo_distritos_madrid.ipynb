# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Datos geo Madrid/geo_distritos.csv',sep =',')
df
# Out:
#                                                    geom  cartodb_id  \
# 0     POLYGON((-3.32053457555518 40.5501017055762, -...       20140
# 1     POLYGON((-3.32579244666982 40.5495847967221, -...       20142
# 2     POLYGON((-3.3222111892899 40.5559343038948, -3...       20143
# 3     POLYGON((-3.31608555683787 40.584073152043, -3...       20141
# 4     POLYGON((-3.30671018189774 40.5785377081149, -...       20139
# ...                                                 ...         ...
# 4339  POLYGON((-4.39693833797757 40.3610322533443, -...       20636
# 4340  POLYGON((-4.34738423209109 40.3628235678141, -...       20637
# 4341  POLYGON((-4.37913453415264 40.4074726222989, -...       20635
# 4342  POLYGON((-3.56858480443603 40.9044289507467, -...       20923
# 4343  POLYGON((-3.6658487391691 40.9954336263361, -3...       17380
#
#       objectid_1  objectid       cusec  cumun  csec  cdis  cmun  cpro  ...  \
# ...
